# %% [markdown]
# ## Get fields of the AA sheet

# %% [markdown]
# Provide a list of names and, in return, receive the same list with sectionsfilled out with input generated by chatGPT

# %%
# pip install country_list>

# %%
# pip install --upgrade openai

# %%
import openai
import time
import pandas as pd
from datetime import datetime as dt

# %%
openai.api_key = "ENTER YOU API KEY"

# %%
def assistant_question(question, role = "assistant"):
    response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo-1106',
#     model='gpt-4-1106-preview',
    messages=[
        {"role": role, "content": question},
    ])

    message = response.choices[0]['message']
    return message["content"].strip("\n\n")

# %%
import pandas as pd
def get_data(file_path):
    data = pd.read_excel(file_path)
    return data

# %%
file_path = "data/Input/Combined_list_input.xlsx"
accounts_list = get_data(file_path)

list_names = accounts_list["Account Name"]
len(accounts_list)
# Out:
# 186

# %% [markdown]
# ### "About us"

# %%
def get_about_us(company, question = "Please provide a 5 sentence detail-oriented description using information that would be useful to a potential investor.\
Please do not cite any specific financial numbers. \
If it exists, please describe their engagment into wealth managemnet business, real estate, fixed income or private equity.\
Do it for the following company: "):
    # Alternative question(s) possible:
    # "Please provide a 5 sentence detail-oriented description using information that describes the business of this particular bank. Do it for the following company: "
    return assistant_question(question+company)

# %%
# Usage example
# get_description(cooperative_banks["Account Name"][0])

# %%
def description_list(names_list):
    descriptions_dict = {}
    descriptions_list = []

    for company_name in names_list:
        description = get_about_us(company_name)
        descriptions_list.append(description)
        descriptions_dict[company_name] = description

    return [descriptions_dict, descriptions_list]

# %%
# list_descriptions = description_list(accounts_list["Account Name"][:3])

# %% [markdown]
# ### "Investment focus"

# %%
def get_inv_focus(company, question = "Please provide a 5 sentence detail-oriented investment focus description using information that describes in what kind \
of asset classes a given company invests in. Do not explicitly mention any of the following: private equity, private debt, real assets, impact investing.\
Please do not cite any specific financial numbers.\
Mention alternative investments if relevant. Do it for the following company: "):
    return assistant_question(question+company)

# %%
# Usage example
# get_inv_focus(cooperative_banks["Account Name"][0])

# %%
def inv_focus_list(names_list):
    inv_focus_dict = {}
    inv_focus_list = []

    for company_name in names_list:
        inv_focus = get_inv_focus(company_name)
        inv_focus_list.append(inv_focus)
        inv_focus_dict[company_name] = inv_focus

    return [inv_focus_dict, inv_focus_list]

# %%
# list_inv_focuses = inv_focus_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Private equity" box

# %%
def get_private_equity_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company invests in private equity.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
# Usage example
# get_private_equity_box(cooperative_banks["Account Name"][1])

# %%
def private_equity_list(names_list):
    private_equity_dict = {}
    private_equity_list = []

    for company_name in names_list:
        private_equity = get_private_equity_box(company_name).replace(".","")
#         if private_equity not in ("TRUE", "FALSE"):
#             private_equity = "FALSE"
        private_equity_list.append(private_equity)
        private_equity_dict[company_name] = private_equity

    return [private_equity_dict, private_equity_list]

# %%
# list_private_equity_boxes = private_equity_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Private debt" box

# %%
def get_private_debt_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company invests in private debt.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def private_debt_list(names_list):
    private_debt_dict = {}
    private_debt_list = []

    for company_name in names_list:
        private_debt = get_private_debt_box(company_name).replace(".","")
#         if private_debt not in ("TRUE", "FALSE"):
#             private_debt = "FALSE"
        private_debt_list.append(private_debt)
        private_debt_dict[company_name] = private_debt

    return [private_debt_dict, private_debt_list]

# %%
# list_private_debt_boxes = private_debt_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Hedge funds" box

# %%
def get_hedge_funds_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company invests in hedge funds.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def hedge_funds_list(names_list):
    hedge_funds_dict = {}
    hedge_funds_list = []

    for company_name in names_list:
        hedge_funds = get_hedge_funds_box(company_name).replace(".","")
#         if hedge_funds not in ("TRUE", "FALSE"):
#             hedge_funds = "FALSE"
        hedge_funds_list.append(hedge_funds)
        hedge_funds_dict[company_name] = hedge_funds

    return [hedge_funds_dict, hedge_funds_list]

# %%
# list_hedge_funds_boxes = hedge_funds_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Real assets" box

# %%
def get_real_assets_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company invests in real assets.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def real_assets_list(names_list):
    real_assets_dict = {}
    real_assets_list = []

    for company_name in names_list:
        real_assets = get_real_assets_box(company_name).replace(".","")
#         if real_assets not in ("TRUE", "FALSE"):
#             real_assets = "FALSE"
        real_assets_list.append(real_assets)
        real_assets_dict[company_name] = real_assets

    return [real_assets_dict, real_assets_list]

# %%
# list_real_assets_boxes = real_assets_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Impact investing" box

# %%
def get_impact_investing_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is involved in impact investing.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def impact_investing_list(names_list):
    impact_investing_dict = {}
    impact_investing_list = []

    for company_name in names_list:
        impact_investing = get_impact_investing_box(company_name).replace(".","")
#         if impact_investing not in ("TRUE", "FALSE"):
#             impact_investing = "FALSE"
        impact_investing_list.append(impact_investing)
        impact_investing_dict[company_name] = impact_investing

    return [impact_investing_dict, impact_investing_list]

# %%
# list_impact_investing_boxes = impact_investing_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Geographic focus"

# %%
def get_preferred_region(company, question = "Please answer with names of countries with a comma and one space in between (if there is more than one), in what countries does the following company invest. If you don't have data or cannot answer, please don't give anything as answer,  just leave it empty, don't give me even a single character.\
Do it for the following company: "):
    list_of_possible_countries = ['Afghanistan', 'Aland Islands', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia, Plurinational State of', 'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana', 'Bouvet Island', 'Brazil', 'British Indian Ocean Territory', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo', 'Congo, The Democratic Republic of the', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'French Southern Territories', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Heard Island and McDonald Islands', 'Holy See (Vatican City State)', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran, Islamic Republic of', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', "Korea, Democratic People's Republic of", 'Korea, Republic of', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Macedonia, Republic of', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia, Federated States of', 'Moldova, Republic of', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island', 'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Palestinian Territory, Occupied', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Réunion', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Barthélemy', 'Saint Helena, Ascension and Tristan da Cunha', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Martin (French part)', 'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'South Georgia and the South Sandwich Islands', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'South Sudan', 'Svalbard and Jan Mayen', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan, Province of China', 'Tajikistan', 'Tanzania, United Republic of', 'Thailand', 'Timor-Leste', 'Togo', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'United States Minor Outlying Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, Bolivarian Republic of', 'Viet Nam', 'Virgin Islands, British', 'Virgin Islands, U.S.', 'Wallis and Futuna', 'Yemen', 'Zambia', 'Zimbabwe']
    
    geographic_focus = assistant_question(question+company)
    
    if geographic_focus not in list_of_possible_countries and geographic_focus.split()[0][:-1] not in list_of_possible_countries:
            geographic_focus = ""
    return geographic_focus

# %%
def geographic_focus_list(names_list):
    geographic_focus_dict = {}
    geographic_focus_list = []
    
    for company_name in names_list:
        geographic_focus = get_preferred_region(company_name).replace(".","")
        geographic_focus_list.append(geographic_focus)
        geographic_focus_dict[company_name] = geographic_focus

    return [geographic_focus_dict, geographic_focus_list]

# %%
# list_geographic_focus_boxes = geographic_focus_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Bond Investments (y/n)" box

# %%
def get_bond_investments_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is invests in bonds.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def bond_investments_list(names_list):
    bond_investments_dict = {}
    bond_investments_list = []

    for company_name in names_list:
        bond_investments = get_bond_investments_box(company_name).replace(".","")
#         if bond_investments not in ("TRUE", "FALSE"):
#             bond_investments = "FALSE"
        bond_investments_list.append(bond_investments)
        bond_investments_dict[company_name] = bond_investments

    return [bond_investments_dict, bond_investments_list]

# %%
# list_bond_investments_boxes = bond_investments_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Direct Bond Investments (y/n)" box

# %%
def get_direct_bond_investments_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is makes direct bond investments.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def direct_bond_investments_list(names_list):
    direct_bond_investments_dict = {}
    direct_bond_investments_list = []

    for company_name in names_list:
        direct_bond_investments = get_direct_bond_investments_box(company_name).replace(".","")
#         if direct_bond_investments not in ("TRUE", "FALSE"):
#             direct_bond_investments = "FALSE"
        direct_bond_investments_list.append(direct_bond_investments)
        direct_bond_investments_dict[company_name] = direct_bond_investments

    return [direct_bond_investments_dict, direct_bond_investments_list]

# %%
# list_direct_bond_investments_boxes = direct_bond_investments_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Indirect Bond Investments (y/n)" box

# %%
def get_indirect_bond_investments_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is makes indirect bond investments.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def indirect_direct_bond_investments_list(names_list):
    indirect_bond_investments_dict = {}
    indirect_bond_investments_list = []

    for company_name in names_list:
        indirect_bond_investments = get_indirect_bond_investments_box(company_name).replace(".","")
#         if indirect_bond_investments not in ("TRUE", "FALSE"):
#             indirect_bond_investments = "FALSE"
        indirect_bond_investments_list.append(indirect_bond_investments)
        indirect_bond_investments_dict[company_name] = indirect_bond_investments

    return [indirect_bond_investments_dict, indirect_bond_investments_list]

# %% [markdown]
# ### "Equities/Stocks (y/n)" box

# %%
def get_equities_stocks_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is invests in equities or stocks.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def equities_stocks_list(names_list):
    equities_stocks_dict = {}
    equities_stocks_list = []

    for company_name in names_list:
        equities_stocks = get_equities_stocks_box(company_name).replace(".","")
#         if equities_stocks not in ("TRUE", "FALSE"):
#             equities_stocks = "FALSE"
        equities_stocks_list.append(equities_stocks)
        equities_stocks_dict[company_name] = equities_stocks

    return [equities_stocks_dict, equities_stocks_list]

# %%
# list_equities_stocks_boxes = equities_stocks_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Loans (y/n)" box

# %%
def get_loans_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is invests in loans.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def loans_list(names_list):
    loans_dict = {}
    loans_list = []

    for company_name in names_list:
        loans = get_loans_box(company_name).replace(".","")
#         if loans not in ("TRUE", "FALSE"):
#             loans = "FALSE"
        loans_list.append(loans)
        loans_dict[company_name] = loans

    return [loans_dict, loans_list]

# %%
# list_loans_boxes = loans_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Real Estate (y/n)" box

# %%
def get_real_estate_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is invests in real estate.\
Do it for the following company: "):
    return assistant_question(question+company)

# %%
def real_estate_list(names_list):
    real_estate_dict = {}
    real_estate_list = []

    for company_name in names_list:
        real_estate = get_real_estate_box(company_name).replace(".","")
#         if real_estate not in ("TRUE", "FALSE"):
#             real_estate = "FALSE"
        real_estate_list.append(real_estate)
        real_estate_dict[company_name] = real_estate

    return [real_estate_dict, real_estate_list]

# %%
# list_real_estate_boxes = real_estate_list(accounts_list["Account Name"])

# %% [markdown]
# ### "Direct Real Estate (y/n)" box

# %%
def get_direct_real_estate_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is invests in direct real estate.\
Do it for the following company: "):
    return assistant_question(question+company)

def direct_real_estate_list(names_list):
    direct_real_estate_dict = {}
    direct_real_estate_list = []

    for company_name in names_list:
        direct_real_estate = get_direct_real_estate_box(company_name).replace(".","")
#         if direct_real_estate not in ("TRUE", "FALSE"):
#             direct_real_estate = "FALSE"
        direct_real_estate_list.append(direct_real_estate)
        direct_real_estate_dict[company_name] = direct_real_estate

    return [direct_real_estate_dict, direct_real_estate_list]

# %%
# direct_list_real_estate_boxes = direct_real_estate_list(accounts_list["Account Name"])

# %% [markdown]
# ### Real Estate Funds (y/n)

# %%
def get_real_estate_funds_box(company, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether the the following company is invests in real estate funds.\
Do it for the following company: "):
    return assistant_question(question+company)

def real_estate_funds_list(names_list):
    real_estate_funds_dict = {}
    real_estate_funds_list = []

    for company_name in names_list:
        real_estate_funds = get_real_estate_funds_box(company_name).replace(".","")
#         if real_estate_funds not in ("TRUE", "FALSE"):
#             real_estate_funds = "FALSE"
        real_estate_funds_list.append(real_estate_funds)
        real_estate_funds_dict[company_name] = real_estate_funds

    return [real_estate_funds_dict, real_estate_funds_list]

# %%
# list_real_estate_funds_boxes = direct_real_estate_funds_list(accounts_list["Account Name"])

# %% [markdown]
# ### Get any (y/n) attribute

# %%
def get_attribute_box(company, question_term, question = "Please answer with literally just one word without any interpunction, TRUE or FALSE, whether {} {}."):
    attribute_value = assistant_question(question.format(company, question_term)).replace(".", "")
#     if attribute_value not in ("TRUE", "FALSE"):
#         attribute_value = "FALSE"
    return attribute_value

# %% [markdown]
# ## Line-by-line approach

# %%
### Suppress warnings on working on pd.df copies
pd.options.mode.chained_assignment = None  # default='warn'

# *************************************************** ADJUST THIS LIST ***************************************************
# Necessary columns with original wording of the asset allocation template sheet
columns_to_add = {"About Us":"",
                  "Investment Focus":"",
                  
                  # Bond investments and subclasses
                  "Bond Investments (y/n)":"", 
                  "Direct Bond Investments (y/n)":"", 
                  "Indirect Bond Investments (y/n)":"",
                  "Equities/Stocks (y/n)":"", 
                  "Loans (y/n)":"", 
                  
                  # Real estate investments and subclasses
                  "Real Estate (y/n)":"", 
                  "Direct Real Estate (y/n)":"", 
                  "Real Estate Funds (y/n)":"", 
                  "RE Fund of Funds (y/n)":"invests in real estate funds of funds",
                  "Close-ended RE Funds (y/n)":"invests in close-ended real estate funds", 
                  "Open-ended RE Funds (y/n)":"invests in open-ended real estate funds",
                  "Listed RE Funds (y/n)":"invests in listed real estate funds", 
                  "Unlisted RE Funds (y/n)":"invests in unlisted real estate funds",
                  "RE Debt (y/n)":"invests in real estate debt",
                  "RE Equity (y/n)":"invests in real estate equity", 
                  "Residential (y/n)":"invests in residential real estate",
                  "Office (y/n)":"invests in office real estate", 
                  "Logistics (y/n)":"invests logistical real estate",
                  "Retail/Shopping (y/n)":"invests in retail or shopping real estate", 
                  "Parking (y/n)":"invests in parking real estate",
                  "Industrial (y/n)":"invests in industrial real estate", 
                  "Healthcare RE (y/n)":"invests in healthcare-related real estate",
                  "Accomodation/Assisted Living (y/n)":"invests in accomodation or assisted living real estate", 
                  "Datacenter (y/n)":"invests in datacenter real estate",
                  "Core RE (y/n)":"invests in core real estate", 
                  "Core+ RE (y/n)":"invests in core plus real estate",
                  "Distressed RE (y/n)":"invests in distressed real estate", 
                  "Opportunistic RE (y/n)":"invests in opportunistic real estate",
                  "Value added RE (y/n)":"invests in value added real estate", 
                  "RE Secondaries (y/n)":"invests in real estate secondaries",
                  
                  # Private equity investments and subclasses
                  "Private Equity (y/n)":"",
                  "Direct PE (y/n)":"invests in direct private equity",
                  "Indirect PE (y/n)":"invests in indirect private equity",
                  "Buy-out (y/n)":"invests in buy-out",
                  "Venture Capital (y/n)":"invests in venture capital",
                  "Venture Debt (y/n)":"invests in venture debt",
                  "Secondaries (y/n)":"invests in secondaries",
                  "Special Situations/Distressed (y/n)":"invests in special situations/distressed",
                  "Artificial Intelligence (y/n)":"invests in artificial intelligence private equity",
                  "Blockchain (y/n)":"invests in blockchain private equity",
                  "Crypto (y/n)":"invests in crypto private equity",
                  "Fashion (y/n)":"invests in fashion private equity",
                  "Finance (y/n)":"invests in finance private equity",
                  "Fintech (y/n)":"invests in fintech private equity",
                  "Healthcare/Pharmaceutical (y/n)":"invests in healthcare/pharmaceutical private equity",
                  "Internet of Things (y/n)":"invests in internet of things private equity",
                  "IT (y/n)":"invests in IT private equity",
                  "Jewelry/Lifestyle (y/n)":"invests in jewelry/lifestyle private equity",
                  "Software (y/n)":"invests in software private equity",
                  "FMCG (y/n)":"invests in FMCG private equity",
                  "Food/Nutrition (y/n)":"invests in food/nutrition private equity",
                  "Agriculture (y/n)":"invests in agriculture private equity",
                  "eCommerce (y/n)":"invests in e-commerce private equity",
                  "Heavy Engineering (y/n)":"invests in heavy engineering private equity",
                  "Electrical Engineering (y/n)":"invests in electrical engineering private equity",
                  "Chemical (y/n)":"invests in chemical private equity",
                  "Manufacturing (y/n)":"invests in manufacturing private equity",
                  "Educational (y/n)":"invests in educational private equity",
                  "Tourism, Parks & Leisure (y/n)":"invests in Tourism, Parks & Leisure private equity",
                  "PE Fund of Funds (y/n)":"invests in private equity fund of funds",
                  "PE Co-Investment":"invests in private equity co-investment",

                  
                  # Private debt investments and subclasses
                  "Private Debt (y/n)":"",
                  "Junior PD (y/n)":"invests in junior private debt",
                  "Senior PD (y/n)":"invests in senior private debt",
                  "Mezzanine PD (y/n)":"invests in mezzanine private debt",
                  "Distressed PD (y/n)":"invests in distressed private debt",
                  "Opportunistic PD (y/n)":"invests in opportunistic private debt",
                  "Direct Lending (y/n)":"invests in direct lending",
                  "Direct Lending Fund (y/n)":"invests in direct lending fund or direct lending funds",
                  "PD Funds (y/n)":"invests in private debt funds",
                  "PD Fund of Funds (y/n)":"invests in private debt fund of funds",
                  "Unitranche (y/n)":"invests in unitranche",
                  
                  # Hedge Funds
                  "Hedge Funds (y/n)":"", 
                  
                  # Real assets and subclasses
                  "Real Assets (y/n)":"",
                  "Infrastructure (y/n)":"invests in infrastructure",
                  "Natural Ressources (y/n)":"invests in natural resources",
                  "Commodities (y/n)":"invests in commoditites",
                  "Agriculture (y/n)":"invests in agriculture",
                  "Capital Assets (y/n)":"invests in capital assets",
                  "Aviation (y/n)":"invests in aviation",
                  "Maritime/Shipping (y/n)":"invests in maritime shipping",
                  "Timber (y/n)":"invests in timber",
                  "Renewables (y/n)":"invests in renewables",
                  
                  # Impact investing and subclasses
                  "Impact Investing (y/n)":"", 
                  "Impact Investments (y/n)":"invests in impact investments",
                  "ESG (y/n)":"invests in ESG", 
                  "Blended Finance (y/n)":"invests in blended finance",
                  "Philantrophy (y/n)":"invests in philantrophy",	
                  "Sustainability (y/n)":"invests in sustainability",
                  
                  "Preferred Region of Investment":""}

# Add necessary columns to the pd.df structure
for column in columns_to_add.keys():
    accounts_list[column] = ""

# Define retry function
waiting_times = [5, 30, 60, 120]
def get_field_value(function, account_name):
    for waiting_time in waiting_times:
        try:
            return function(account_name)
        except:
            time.sleep(waiting_time)
    return "RECURRING ERROR - NO VALUE RETRIEVED"

def get_attribute_value(function, account_name, question_term):
    for waiting_time in waiting_times:
        try:
            return function(account_name, question_term)
        except:
            time.sleep(waiting_time)
    return "RECURRING ERROR - NO VALUE RETRIEVED"

# Go account by account
for account_number in range(len(accounts_list)):
    print("\n\nCurrent time:", dt.now().strftime("%H:%M:%S"), "\nIteration: ", account_number + 1, "\nAccount: ", list_names[account_number])

    # About Us
    accounts_list["About Us"][account_number] = get_field_value(get_about_us, list_names[account_number])

    # Investment Focus
    accounts_list["Investment Focus"][account_number] = get_field_value(get_inv_focus, list_names[account_number])

    # Bond Investments
    accounts_list["Bond Investments (y/n)"][account_number] = get_field_value(get_bond_investments_box, list_names[account_number]).replace(".", "")
    accounts_list["Direct Bond Investments (y/n)"][account_number] = get_field_value(get_direct_bond_investments_box, list_names[account_number]).replace(".", "")
    accounts_list["Indirect Bond Investments (y/n)"][account_number] = get_field_value(get_indirect_bond_investments_box, list_names[account_number]).replace(".", "")

    # Equities and stocks
    accounts_list["Equities/Stocks (y/n)"][account_number] = get_field_value(get_equities_stocks_box,list_names[account_number]).replace(".", "")

    # Loans
    accounts_list["Loans (y/n)"][account_number] = get_field_value(get_loans_box, list_names[account_number]).replace(".", "")

    # Real estate
    accounts_list["Real Estate (y/n)"][account_number] = get_field_value(get_real_estate_box, list_names[account_number]).replace(".", "")
    accounts_list["Direct Real Estate (y/n)"][account_number] = get_field_value(get_direct_real_estate_box, list_names[account_number]).replace(".", "")
    accounts_list["Real Estate Funds (y/n)"][account_number] = get_field_value(get_real_estate_funds_box, list_names[account_number]).replace(".", "")    
    accounts_list["RE Fund of Funds (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["RE Fund of Funds (y/n)"]).replace(".", "")
    accounts_list["Close-ended RE Funds (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Close-ended RE Funds (y/n)"]).replace(".", "")
    accounts_list["Open-ended RE Funds (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Open-ended RE Funds (y/n)"]).replace(".", "")
    accounts_list["Listed RE Funds (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Listed RE Funds (y/n)"]).replace(".", "")
    accounts_list["Unlisted RE Funds (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Unlisted RE Funds (y/n)"]).replace(".", "")
    accounts_list["RE Debt (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["RE Debt (y/n)"]).replace(".", "")
    accounts_list["RE Equity (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["RE Equity (y/n)"]).replace(".", "")
    accounts_list["Residential (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Residential (y/n)"]).replace(".", "")
    accounts_list["Office (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Office (y/n)"]).replace(".", "")
    accounts_list["Logistics (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Logistics (y/n)"]).replace(".", "")
    accounts_list["Retail/Shopping (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Retail/Shopping (y/n)"]).replace(".", "")
    accounts_list["Parking (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Parking (y/n)"]).replace(".", "")
    accounts_list["Industrial (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Industrial (y/n)"]).replace(".", "")
    accounts_list["Healthcare RE (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Healthcare RE (y/n)"]).replace(".", "")
    accounts_list["Accomodation/Assisted Living (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Accomodation/Assisted Living (y/n)"]).replace(".", "")
    accounts_list["Datacenter (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Datacenter (y/n)"]).replace(".", "")
    accounts_list["Core RE (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Core RE (y/n)"]).replace(".", "")
    accounts_list["Core+ RE (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Core+ RE (y/n)"]).replace(".", "")
    accounts_list["Distressed RE (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Distressed RE (y/n)"]).replace(".", "")
    accounts_list["Opportunistic RE (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Opportunistic RE (y/n)"]).replace(".", "")
    accounts_list["Value added RE (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Value added RE (y/n)"]).replace(".", "")
    accounts_list["RE Secondaries (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["RE Secondaries (y/n)"]).replace(".", "")                               

    # Private equity
    accounts_list["Private Equity (y/n)"][account_number] = get_field_value(get_private_equity_box, list_names[account_number]).replace(".", "")
    accounts_list["Direct PE (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Direct PE (y/n)"]).replace(".", "")
    accounts_list["Indirect PE (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Indirect PE (y/n)"]).replace(".", "")
    accounts_list["Buy-out (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Buy-out (y/n)"]).replace(".", "")
    accounts_list["Venture Capital (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Venture Capital (y/n)"]).replace(".", "")
    accounts_list["Venture Debt (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Venture Debt (y/n)"]).replace(".", "")
    accounts_list["Secondaries (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Secondaries (y/n)"]).replace(".", "")
    accounts_list["Special Situations/Distressed (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Special Situations/Distressed (y/n)"]).replace(".", "")
    accounts_list["Artificial Intelligence (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Artificial Intelligence (y/n)"]).replace(".", "")
    accounts_list["Blockchain (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Blockchain (y/n)"]).replace(".", "")
    accounts_list["Crypto (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Crypto (y/n)"]).replace(".", "")
    accounts_list["Fashion (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Fashion (y/n)"]).replace(".", "")
    accounts_list["Finance (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Finance (y/n)"]).replace(".", "")
    accounts_list["Fintech (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Fintech (y/n)"]).replace(".", "")
    accounts_list["Healthcare/Pharmaceutical (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Healthcare/Pharmaceutical (y/n)"]).replace(".", "")
    accounts_list["Internet of Things (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Internet of Things (y/n)"]).replace(".", "")
    accounts_list["IT (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["IT (y/n)"]).replace(".", "")
    accounts_list["Jewelry/Lifestyle (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Jewelry/Lifestyle (y/n)"]).replace(".", "")
    accounts_list["Software (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Software (y/n)"]).replace(".", "")
    accounts_list["FMCG (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["FMCG (y/n)"]).replace(".", "")
    accounts_list["Food/Nutrition (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Food/Nutrition (y/n)"]).replace(".", "")
    accounts_list["Agriculture (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Agriculture (y/n)"]).replace(".", "")
    accounts_list["eCommerce (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["eCommerce (y/n)"]).replace(".", "")
    accounts_list["Heavy Engineering (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Heavy Engineering (y/n)"]).replace(".", "")
    accounts_list["Electrical Engineering (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Electrical Engineering (y/n)"]).replace(".", "")
    accounts_list["Chemical (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Chemical (y/n)"]).replace(".", "")
    accounts_list["Manufacturing (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Manufacturing (y/n)"]).replace(".", "")
    accounts_list["Educational (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Educational (y/n)"]).replace(".", "")
    accounts_list["Tourism, Parks & Leisure (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Tourism, Parks & Leisure (y/n)"]).replace(".", "")
    accounts_list["PE Fund of Funds (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["PE Fund of Funds (y/n)"]).replace(".", "")
    accounts_list["PE Co-Investment"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["PE Co-Investment"]).replace(".", "")
    
    # Private Debt
    accounts_list["Private Debt (y/n)"][account_number] = get_field_value(get_private_debt_box, list_names[account_number]).replace(".", "")
    accounts_list["Junior PD (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Junior PD (y/n)"]).replace(".", "")
    accounts_list["Senior PD (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Senior PD (y/n)"]).replace(".", "")
    accounts_list["Mezzanine PD (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Mezzanine PD (y/n)"]).replace(".", "")
    accounts_list["Distressed PD (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Distressed PD (y/n)"]).replace(".", "")
    accounts_list["Opportunistic PD (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Opportunistic PD (y/n)"]).replace(".", "")
    accounts_list["Direct Lending (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Direct Lending (y/n)"]).replace(".", "")
    accounts_list["Direct Lending Fund (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Direct Lending Fund (y/n)"]).replace(".", "")
    accounts_list["PD Funds (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["PD Funds (y/n)"]).replace(".", "")
    accounts_list["PD Fund of Funds (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["PD Fund of Funds (y/n)"]).replace(".", "")
    accounts_list["Unitranche (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Unitranche (y/n)"]).replace(".", "")

    # Hedge funds
    accounts_list["Hedge Funds (y/n)"][account_number] = get_field_value(get_hedge_funds_box, list_names[account_number]).replace(".", "")

    # Real assets
    accounts_list["Real Assets (y/n)"][account_number] = get_field_value(get_real_assets_box, list_names[account_number]).replace(".", "")
    accounts_list["Infrastructure (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Infrastructure (y/n)"]).replace(".", "")
    accounts_list["Natural Ressources (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Natural Ressources (y/n)"]).replace(".", "")
    accounts_list["Commodities (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Commodities (y/n)"]).replace(".", "")
    accounts_list["Agriculture (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Agriculture (y/n)"]).replace(".", "")
    accounts_list["Capital Assets (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Capital Assets (y/n)"]).replace(".", "")
    accounts_list["Timber (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Timber (y/n)"]).replace(".", "")
    accounts_list["Aviation (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Aviation (y/n)"]).replace(".", "")
    accounts_list["Maritime/Shipping (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Maritime/Shipping (y/n)"]).replace(".", "")
    accounts_list["Renewables (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Renewables (y/n)"]).replace(".", "")
   
    # Impact investing
    accounts_list["Impact Investing (y/n)"][account_number] = get_field_value(get_impact_investing_box, list_names[account_number]).replace(".", "")
    accounts_list["Impact Investments (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Impact Investments (y/n)"]).replace(".", "")                               
    accounts_list["ESG (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["ESG (y/n)"]).replace(".", "")                                   
    accounts_list["Blended Finance (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Blended Finance (y/n)"]).replace(".", "")                                   
    accounts_list["Philantrophy (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Philantrophy (y/n)"]).replace(".", "")                                   
    accounts_list["Sustainability (y/n)"][account_number] = get_attribute_value(get_attribute_box, list_names[account_number], columns_to_add["Sustainability (y/n)"]).replace(".", "")                                   
    
    # Preferred region
    accounts_list["Preferred Region of Investment"][account_number] = get_field_value(get_preferred_region, list_names[account_number])

    # Dump current progress to .xlsx
    accounts_list.to_excel("data/output/Combined_list_output.xlsx", index=False)
# Out:
# Current time: 13:07:29
# Iteration:  1
# Account:  Union Asset Management Holding AG
#
#
# Current time: 13:09:01
# Iteration:  2
# Account:  BNP PARIBAS ASSET MANAGEMENT Holding
#
#
# Current time: 13:10:29
# Iteration:  3
# Account:  Ardian (Germany)
#
#
# Current time: 13:11:53
# Iteration:  4
# Account:  Ardian
#
#
# Current time: 13:13:22
# Iteration:  5
# Account:  Ardian (Switzerland)
#
#
# Current time: 13:14:48
# Iteration:  6
# Account:  Pathway Capital Management (UK) Limited
#
#
# Current time: 13:16:11
# Iteration:  7
# Account:  UBS Asset Management Real Estate & Private Markets (REPM)
#
#
# Current time: 13:17:41
# Iteration:  8
# Account:  Pantheon Ventures (UK) LLP
#
#
# Current time: 13:19:04
# Iteration:  9
# Account:  Amundi Real Assets (ARA)
#
#
# Current time: 13:20:28
# Iteration:  10
# Account:  Provinzial Asset Management GmbH (ProAM)
#
#
# Current time: 13:21:56
# Iteration:  11
# Account:  BlackRock Private Equity Partners (Switzerland)
#
#
# ...

# %%
1
# Out:
# 1
